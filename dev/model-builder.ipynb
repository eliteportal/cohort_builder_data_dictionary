# %%
# PACKAGES
import os
import pandas as pd
import numpy as np
import pathlib
from toolbox import utils
from localutils import localcube

# MAIN VARIABLES
csv_model, json_model, manifest_basename = localcube.import_config()

# Get tables to build from
syn = utils.synLogin()
# Out:
# UPGRADE AVAILABLE
#
# A more recent version of the Synapse Client (3.1.1) is available. Your version (2.7.0) can be upgraded by typing:
#     pip install --upgrade synapseclient
#
# Python Synapse Client version 3.1.1 release notes
#
# https://python-docs.synapse.org/build/html/news.html
# Welcome, Nicholas Lee!

# %% [markdown]
# # Templates
#
# - File Map for Individuals
# - Individuals?

# %%
# Base columns
dm = pd.read_csv(csv_model)
dm.head()
# Out:
#              Attribute                                        Description  \
# 0                Assay                                                NaN
# 1         DataProperty                              teesting in schematic
# 2            Diagnosis                                                NaN
# 3  FileMapToIndividual  Template that maps each individual to a file i...
# 4  Individual Metadata              Information related to the individual
#
#               Valid Values                                           Required  \
# 0  snpArray,wholeGenomeSeq                                              False
# 1                      NaN                                                NaN
# 2                      NaN                                              False
# 3                      NaN                                              False
# 4                    False  individualId, minAge, maxAge, Sex, Study, Diag...
#
#                DependsOn DependsOn Component    Properties Validation Rules  \
# 0                    NaN                 NaN  DataProperty              NaN
# 1                    NaN                 NaN           NaN              NaN
# 2                    NaN                 NaN           NaN              NaN
# 3  fileName,individualId                 NaN      Template              NaN
# 4                    NaN            Template           NaN              NaN
#
#    Template        Parent  Source              Type          Ontology  \
# 0       NaN      Template     NaN               NaN  Sage Bionetworks
# 1       NaN      Template     NaN               NaN  Sage Bionetworks
# 2       NaN  DataProperty     NaN               NaN  Sage Bionetworks
# 3      Self      Template     NaN               NaN  Sage Bionetworks
# 4  Template           NaN     NaN  Sage Bionetworks               NaN
#
#    Multivalue          UsedIn          Module  DependsOn ComponentRequired
# 0         NaN             NaN  Cohort Builder                          NaN
# 1         NaN             NaN             NaN                          NaN
# 2         NaN             NaN  Cohort Builder                          NaN
# 3         NaN             NaN  Cohort Builder                          NaN
# 4         NaN  Cohort Builder             NaN                          NaN

# %%
# File mapping
ref_df = syn.tableQuery("SELECT * FROM syn52234184").asDataFrame()
ref_df
# Out:
# [WARNING] /Users/nlee/Library/Caches/pypoetry/virtualenvs/cohort-builder-data-dictionary-fOfjgXmU-py3.10/lib/python3.10/site-packages/synapseclient/table.py:596: DtypeWarning: Columns (19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filepath,
#                fileId                                      fileName Species  \
# 1_0       syn25926091                                      test.txt     NaN
# 2_0       syn25931995                                  SWS_data.zip     NaN
# 3_0       syn26143168                            analyte_ranges.csv     NaN
# 4_0       syn26143169                               assessments.csv     NaN
# 5_0       syn26143170                            blood_pressure.csv     NaN
# ...               ...                                           ...     ...
# 535662_0  syn52784222      LLFS.WGS.freeze5.chr22ck04.BI-SNP.vcf.gz     NaN
# 535663_0  syn52784223  LLFS.WGS.freeze5.chr22ck04.BI-SNP.vcf.gz.tbi     NaN
# 535664_0  syn52784224      LLFS.WGS.freeze5.chr22ck05.BI-SNP.vcf.gz     NaN
# 535665_0  syn52784225  LLFS.WGS.freeze5.chr22ck05.BI-SNP.vcf.gz.tbi     NaN
# 535666_0  syn52915157               ADAMTS7-individual-metadata.csv     NaN
#
#          individualID  minAge  maxAge familyStudyParticipant         dataType  \
# 1_0               NaN     NaN     NaN                    NaN              NaN
# 2_0               NaN     NaN     NaN                    NaN              NaN
# 3_0               NaN     NaN     NaN                    NaN              NaN
# 4_0               NaN     NaN     NaN                    NaN              NaN
# 5_0               NaN     NaN     NaN                    NaN              NaN
# ...               ...     ...     ...                    ...              ...
# 535662_0          NaN     NaN     NaN                     No  genomicVariants
# 535663_0          NaN     NaN     NaN                     No  genomicVariants
# 535664_0          NaN     NaN     NaN                     No  genomicVariants
# 535665_0          NaN     NaN     NaN                     No  genomicVariants
# 535666_0          NaN     NaN     NaN                    NaN              NaN
#
#           Sex Study  ... Consortium Grant isModelSystem isMultiSpecimen  \
# 1_0       NaN   NaN  ...        NaN   NaN           NaN             NaN
# 2_0       NaN   NaN  ...        NaN   NaN           NaN             NaN
# 3_0       NaN   NaN  ...        NaN   NaN           NaN             NaN
# 4_0       NaN   NaN  ...        NaN   NaN           NaN             NaN
# 5_0       NaN   NaN  ...        NaN   NaN           NaN             NaN
# ...       ...   ...  ...        ...   ...           ...             ...
# 535662_0  NaN   NaN  ...        NaN   NaN           NaN             NaN
# 535663_0  NaN   NaN  ...        NaN   NaN           NaN             NaN
# 535664_0  NaN   NaN  ...        NaN   NaN           NaN             NaN
# 535665_0  NaN   NaN  ...        NaN   NaN           NaN             NaN
# 535666_0  NaN   NaN  ...        NaN   NaN           NaN             NaN
#
#          metadataType modelSystemType Platform Project ResourceType  \
# 1_0               NaN             NaN      NaN     NaN          NaN
# 2_0               NaN             NaN      NaN     NaN          NaN
# 3_0               NaN             NaN      NaN     NaN          NaN
# 4_0               NaN             NaN      NaN     NaN          NaN
# 5_0               NaN             NaN      NaN     NaN          NaN
# ...               ...             ...      ...     ...          ...
# 535662_0          NaN             NaN      NaN     NaN          NaN
# 535663_0          NaN             NaN      NaN     NaN          NaN
# 535664_0          NaN             NaN      NaN     NaN          NaN
# 535665_0          NaN             NaN      NaN     NaN          NaN
# 535666_0   individual             NaN      NaN     NaN     metadata
#
#          currentVersion
# 1_0                   1
# 2_0                   1
# 3_0                   1
# 4_0                   1
# 5_0                   1
# ...                 ...
# 535662_0              1
# 535663_0              1
# 535664_0              1
# 535665_0              1
# 535666_0              1
#
# [535666 rows x 25 columns]

# %% [markdown]
# - fileId, fileSize, and currentVersion should already be in synapse
# - dataType, dataSubtype, Assay, fileFormat are annotations that should be pulled in from manifests
# - individual related metadata will be pull from individual manifests within projects

# %%
new_dm = [
    {
        "Attribute": "Individual Metadata",
        "Description": "Template for mapping individuals to files in synapse",
        "Valid Values": "",
        "DependsOn": "individualId, minAge, maxAge, Sex, Study, Diagnosis",
        "DependsOn Component": "",
        "Required": "False",
        "Properties": "Template",
        "Validation Rules": "",
        "Template": "",
        "Parent": "Template",
        "Ontology": "Sage Bionetworks",
        "UsedIn": "",
        "Module": "Cohort Builder",
    },
    {
        "Attribute": "Study",
        "Description": "",
        "Valid Values": "LLFS",
        "DependsOn": "",
        "DependsOn Component": "",
        "Required": "False",
        "Properties": "",
        "Validation Rules": "",
        "Template": "",
        "Parent": "DataProperty",
        "Ontology": "Sage Bionetworks",
        "UsedIn": "",
        "Module": "Cohort Builder",
    },
    {
        "Attribute": "minAge",
        "Description": "Masked age of individual that is the minimum age found across files",
        "Valid Values": "",
        "DependsOn": "",
        "DependsOn Component": "",
        "Required": "False",
        "Properties": "",
        "Validation Rules": "int",
        "Template": "",
        "Parent": "DataProperty",
        "Ontology": "Sage Bionetworks",
        "UsedIn": "",
        "Module": "Cohort Builder",
    },
    {
        "Attribute": "maxAge",
        "Description": "Masked age of individual that is the maximum age found across files",
        "Valid Values": "",
        "DependsOn": "",
        "DependsOn Component": "",
        "Required": "False",
        "Properties": "",
        "Validation Rules": "int",
        "Template": "",
        "Parent": "DataProperty",
        "Ontology": "Sage Bionetworks",
        "UsedIn": "",
        "Module": "Cohort Builder",
    },
    {
        "Attribute": "Diagnosis",
        "Description": "",
        "Valid Values": "",
        "DependsOn": "",
        "DependsOn Component": "",
        "Required": "False",
        "Properties": "",
        "Validation Rules": "",
        "Template": "",
        "Parent": "DataProperty",
        "Ontology": "Sage Bionetworks",
        "UsedIn": "",
        "Module": "Cohort Builder",
    },
    {
        "Attribute": "LLFS",
        "Description": "",
        "Valid Values": "",
        "DependsOn": "",
        "DependsOn Component": "",
        "Required": "False",
        "Properties": "",
        "Validation Rules": "",
        "Template": "",
        "Parent": "ValidValue",
        "Ontology": "Sage Bionetworks",
        "UsedIn": "",
        "Module": "Cohort Builder",
    },
    {
        "Attribute": "Assay",
        "Description": "",
        "Valid Values": "snpArray, 'wholeGenomeSeq",
        "DependsOn": "",
        "DependsOn Component": "",
        "Required": "False",
        "Properties": "DataProperty",
        "Validation Rules": "",
        "Template": "",
        "Parent": "Template",
        "Ontology": "Sage Bionetworks",
        "UsedIn": "",
        "Module": "Cohort Builder",
    },
    {
        "Attribute": "snpArray",
        "Description": "",
        "Valid Values": "",
        "DependsOn": "",
        "DependsOn Component": "",
        "Required": "False",
        "Properties": "",
        "Validation Rules": "",
        "Template": "",
        "Parent": "ValidValue",
        "Ontology": "Sage Bionetworks",
        "UsedIn": "",
        "Module": "Cohort Builder",
    },
    {
        "Attribute": "wholeGenomeSeq",
        "Description": "",
        "Valid Values": "snpArray, 'wholeGenomeSeq",
        "DependsOn": "",
        "DependsOn Component": "",
        "Required": "False",
        "Properties": "DataProperty",
        "Validation Rules": "",
        "Template": "",
        "Parent": "ValidValue",
        "Ontology": "Sage Bionetworks",
        "UsedIn": "",
        "Module": "Cohort Builder",
    },
    {
        "Attribute": "FileMapToIndividual",
        "Description": "Template for mapping individuals to files in synapse",
        "Valid Values": "",
        "DependsOn": "fileName, individualId",
        "DependsOn Component": "Individual Metadata",
        "Required": "False",
        "Properties": "Template",
        "Validation Rules": "",
        "Template": "",
        "Parent": "Template",
        "Ontology": "Sage Bionetworks",
        "UsedIn": "",
        "Module": "Cohort Builder",
    },
    {
        "Attribute": "fileName",
        "Description": "Name of the file",
        "Valid Values": "",
        "DependsOn": "",
        "Required": "True",
        "Properties": "DataProperty",
        "Validation Rules": "str",
        "Template": "FileToIndividualMap",
        "Parent": "DataProperty",
        "Ontology": "Sage Bionetworks",
        "UsedIn": "FileToIndividualMap",
        "Module": "Cohort Builder",
    },
    {
        "Attribute": "individualId",
        "Description": "Unique individual identifier",
        "Valid Values": "",
        "DependsOn": "",
        "Required": "True",
        "Properties": "DataProperty",
        "Validation Rules": "str",
        "Template": "FileToIndividualMap",
        "Parent": "DataProperty",
        "Ontology": "Sage Bionetworks",
        "UsedIn": "FileToIndividualMap",
        "Module": "Cohort Builder",
    },
    {
        "Attribute": "Template",
        "Description": "Template property for data model",
        "Valid Values": "",
        "DependsOn": "",
        "DependsOn Component" "Required": "",
        "Properties": "",
        "Validation Rules": "",
        "Template": "",
        "Parent": "Schema",
        "Ontology": "Sage Bionetworks",
        "UsedIn": "",
        "Module": "",
    },
    {
        "Attribute": "DataProperty",
        "Description": "Column for manifests",
        "Valid Values": "",
        "DependsOn": "",
        "Required": "",
        "Properties": "",
        "Validation Rules": "",
        "Template": "",
        "Parent": "Schema",
        "Ontology": "Sage Bionetworks",
        "UsedIn": "",
        "Module": "",
    },
    {
        "Attribute": "ValidValue",
        "Description": "valid value for dataProperty",
        "Valid Values": "",
        "DependsOn": "",
        "Required": "",
        "Properties": "",
        "Validation Rules": "",
        "Template": "",
        "Parent": "DataProperty",
        "Ontology": "Sage Bionetworks",
        "UsedIn": "",
        "Module": "",
    },
    {
        "Attribute": "Schema",
        "Description": "Schema property used in parent column",
        "Valid Values": "",
        "DependsOn": "",
        "Required": "",
        "Properties": "",
        "Validation Rules": "",
        "Template": "",
        "Parent": "",
        "Ontology": "Sage Bionetworks",
        "UsedIn": "",
        "Module": "",
    },
]

# %%
new_dm = pd.concat([dm, pd.DataFrame.from_dict(new_dm)])
print("Duplicates: ", sum(new_dm.duplicated(subset="Attribute")))
new_dm = new_dm.replace("", np.nan)
new_dm = new_dm.drop_duplicates(subset="Attribute", keep="first").sort_values(
    by=["Attribute"]
)

new_dm
# Out:
# Duplicates:  15
#               Attribute                                        Description  \
# 0                 Assay                                                NaN
# 1          DataProperty                              teesting in schematic
# 2             Diagnosis                                                NaN
# 3   FileMapToIndividual  Template that maps each individual to a file i...
# 4   Individual Metadata              Information related to the individual
# 5                  LLFS                                                NaN
# 5                Schema              Schema property used in parent column
# 6                 Study                                                NaN
# 7              Template                                 templalpte for dca
# 8            ValidValue                 Valid value to be added to columns
# 9              fileName                                   Name of the file
# 10         individualId  Unique individual identifier defined by the co...
# 11               maxAge                                                NaN
# 12               minAge                                                NaN
# 13             snpArray                                                NaN
# 14       wholeGenomeSeq                                                NaN
#
#                  Valid Values  \
# 0     snpArray,wholeGenomeSeq
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                       False
# 5                         NaN
# 5                         NaN
# 6              LLFS,ILO,LC,LG
# 7                         NaN
# 8                         NaN
# 9                         NaN
# 10                        NaN
# 11                        NaN
# 12                        NaN
# 13                        NaN
# 14  snpArray, 'wholeGenomeSeq
#
#                                              Required              DependsOn  \
# 0                                               False                    NaN
# 1                                                 NaN                    NaN
# 2                                               False                    NaN
# 3                                               False  fileName,individualId
# 4   individualId, minAge, maxAge, Sex, Study, Diag...                    NaN
# 5                                               False                    NaN
# 5                                                 NaN                    NaN
# 6                                               False                    NaN
# 7                                                 NaN                    NaN
# 8                                                 NaN                    NaN
# 9                                                True                    NaN
# 10                                               True                    NaN
# 11                                              False                    NaN
# 12                                              False                    NaN
# 13                                              False                    NaN
# 14                                              False                    NaN
#
#    DependsOn Component    Properties Validation Rules             Template  \
# 0                  NaN  DataProperty              NaN                  NaN
# 1                  NaN           NaN              NaN                  NaN
# 2                  NaN           NaN              NaN                  NaN
# 3                  NaN      Template              NaN                 Self
# 4             Template           NaN              NaN             Template
# 5                  NaN           NaN              NaN                  NaN
# 5                  NaN           NaN              NaN                  NaN
# 6                  NaN           NaN              NaN                  NaN
# 7                  NaN           NaN              NaN                  NaN
# 8                  NaN        schema              NaN                  NaN
# 9                  NaN  DataProperty              str  FileToIndividualMap
# 10                 NaN  DataProperty              str  FileToIndividualMap
# 11                 NaN           NaN              int                  NaN
# 12                 NaN           NaN              int                  NaN
# 13                 NaN           NaN              NaN                  NaN
# 14                 NaN  DataProperty              NaN                  NaN
#
#           Parent  Source              Type          Ontology  Multivalue  \
# 0       Template     NaN               NaN  Sage Bionetworks         NaN
# 1       Template     NaN               NaN  Sage Bionetworks         NaN
# 2   DataProperty     NaN               NaN  Sage Bionetworks         NaN
# 3       Template     NaN               NaN  Sage Bionetworks         NaN
# 4            NaN     NaN  Sage Bionetworks               NaN         NaN
# 5     ValidValue     NaN               NaN  Sage Bionetworks         NaN
# 5            NaN     NaN               NaN  Sage Bionetworks         NaN
# 6   DataProperty     NaN               NaN  Sage Bionetworks         NaN
# 7            NaN     NaN               NaN  Sage Bionetworks         NaN
# 8   DataProperty     NaN               NaN  Sage Bionetworks         NaN
# 9   DataProperty     NaN               NaN  Sage Bionetworks         NaN
# 10  DataProperty     NaN               NaN  Sage Bionetworks         NaN
# 11  DataProperty     NaN               NaN  Sage Bionetworks         NaN
# 12  DataProperty     NaN               NaN  Sage Bionetworks         NaN
# 13    ValidValue     NaN               NaN  Sage Bionetworks         NaN
# 14    ValidValue     NaN               NaN  Sage Bionetworks         NaN
#
#                  UsedIn          Module  DependsOn ComponentRequired
# 0                   NaN  Cohort Builder                          NaN
# 1                   NaN             NaN                          NaN
# 2                   NaN  Cohort Builder                          NaN
# 3                   NaN  Cohort Builder                          NaN
# 4        Cohort Builder             NaN                          NaN
# 5                   NaN  Cohort Builder                          NaN
# 5                   NaN             NaN                          NaN
# 6                   NaN  Cohort Builder                          NaN
# 7                   NaN             NaN                          NaN
# 8                   NaN             NaN                          NaN
# 9   FileToIndividualMap  Cohort Builder                          NaN
# 10  FileToIndividualMap  Cohort Builder                          NaN
# 11                  NaN  Cohort Builder                          NaN
# 12                  NaN  Cohort Builder                          NaN
# 13                  NaN  Cohort Builder                          NaN
# 14                  NaN  Cohort Builder                          NaN

# %%
new_dm.to_csv(csv_model, index=False)

# %%
# Create schematic model
localcube.create_json_model(csv_model, json_model)
# Out:
# Running
#  schematic schema convert /Users/nlee/Documents/Projects/cohort_builder_data_dictionary/cohort-builder-model.csv --output_jsonld /Users/nlee/Documents/Projects/cohort_builder_data_dictionary/cohort-builder-model.jsonld
# Starting schematic...
# Done adding requirements and value ranges to attributes
# The Data Model was created and saved to '/Users/nlee/Documents/Projects/cohort_builder_data_dictionary/cohort-builder-model.jsonld' location.
# Finished
