# %%
# PACKAGES
import os
import pandas as pd
import numpy as np
import pathlib
from toolbox import utils
from localutils import localcube

# MAIN VARIABLES
csv_model, json_model, manifest_basename = localcube.import_config()

# Get tables to build from
syn = utils.synLogin()
# Out:
# UPGRADE AVAILABLE
#
# A more recent version of the Synapse Client (3.0.0) is available. Your version (2.7.0) can be upgraded by typing:
#     pip install --upgrade synapseclient
#
# Python Synapse Client version 3.0.0 release notes
#
# https://python-docs.synapse.org/build/html/news.html
# Welcome, Nicholas Lee!

# %% [markdown]
# # Templates
#
# - File Map for Individuals
# - Individuals?

# %%
# Base columns
dm = pd.read_csv(csv_model)
dm.head()
# Out:
#              Attribute                   Description  Valid Values Required  \
# 0  FileMapToIndividual                      Template           NaN    False
# 1             fileName              Name of the file           NaN     True
# 2         individualId  Unique individual identifier           NaN     True
# 3             Template            templalpte for dca           NaN      NaN
# 4         DataProperty         teesting in schematic           NaN      NaN
#
#                 DependsOn  DependsOn Component    Properties Validation Rules  \
# 0  fileName, individualId                  NaN      Template              NaN
# 1                     NaN                  NaN  DataProperty              str
# 2                     NaN                  NaN  DataProperty              str
# 3                     NaN                  NaN           NaN              NaN
# 4                     NaN                  NaN           NaN              NaN
#
#               Template        Parent  Source  Type          Ontology  \
# 0                 Self      Template     NaN   NaN  Sage Bionetworks
# 1  FileToIndividualMap  DataProperty     NaN   NaN  Sage Bionetworks
# 2  FileToIndividualMap  DataProperty     NaN   NaN  Sage Bionetworks
# 3                  NaN           NaN     NaN   NaN  Sage Bionetworks
# 4                  NaN      Template     NaN   NaN  Sage Bionetworks
#
#    Multivalue               UsedIn          Module
# 0         NaN                  NaN  Cohort Builder
# 1         NaN  FileToIndividualMap  Cohort Builder
# 2         NaN  FileToIndividualMap  Cohort Builder
# 3         NaN                  NaN             NaN
# 4         NaN                  NaN             NaN

# %%
# File mapping
ref_df = syn.tableQuery("SELECT * FROM syn52234184").asDataFrame()
ref_df
# Out:
#              fileId                                           fileName  \
# 1_0     syn32405375  Province_Release_FinalReport_29848835_01053597...
# 2_0     syn45341061                                 H_ZK-29848835.cram
# 3_0     syn32369868  Province_Release_FinalReport_44901514_01053596...
# 4_0     syn35355319                                 H_ZK-44901514.cram
# 5_0     syn32405337  Province_Release_FinalReport_29847282_01053599...
# ...             ...                                                ...
# 9239_0  syn32427183  Province_Release_FinalReport_14755111_01053577...
# 9240_0  syn39172902                                 H_ZK-14755111.cram
# 9241_0  syn32421750  Province_Release_FinalReport_12025731_01053579...
# 9242_0  syn34512686                                 H_ZK-12025731.cram
# 9243_0  syn32422384  Province_Release_FinalReport_12358990_01053578...
#
#            fileSize individualID  minAge  maxAge         dataType     Sex  \
# 1_0       242769568   22OUCENCZT    49.0    49.0  genomicVariants  Female
# 2_0     15498619914   22OUCENCZT    49.0    49.0  genomicVariants  Female
# 3_0       242780294   22RSJNL2BM    57.0    57.0  genomicVariants    Male
# 4_0     14018970393   22RSJNL2BM    57.0    57.0  genomicVariants    Male
# 5_0       243001057   23EYRGKYID    81.0    81.0  genomicVariants  Female
# ...             ...          ...     ...     ...              ...     ...
# 9239_0    243304788   ZYY4YU46WF    60.0    60.0  genomicVariants  Female
# 9240_0  20444889805   ZYY4YU46WF    60.0    60.0  genomicVariants  Female
# 9241_0    243099999   ZZNSAFEXPD    90.0    94.0  genomicVariants    Male
# 9242_0  15310301964   ZZNSAFEXPD    90.0    94.0  genomicVariants    Male
# 9243_0    243189016   ZZVYBDJPAE    72.0    72.0  genomicVariants  Female
#
#        Study                                          Diagnosis dataSubtype  \
# 1_0     LLFS                                             [None]         raw
# 2_0     LLFS                                             [None]         raw
# 3_0     LLFS                                             [None]         raw
# 4_0     LLFS                                             [None]         raw
# 5_0     LLFS  [Alzheimer  Or Dementia, Breast Cancer, Osteop...         raw
# ...      ...                                                ...         ...
# 9239_0  LLFS                                             [None]         raw
# 9240_0  LLFS                                             [None]         raw
# 9241_0  LLFS                                  [Prostate Cancer]         raw
# 9242_0  LLFS                                  [Prostate Cancer]         raw
# 9243_0  LLFS             [Colon Or Rectal Cancer, Lung Disease]         raw
#
#                  Assay fileFormat  currentVersion
# 1_0           snpArray        csv               2
# 2_0     wholeGenomeSeq       cram               2
# 3_0           snpArray        csv               2
# 4_0     wholeGenomeSeq       cram               2
# 5_0           snpArray        csv               2
# ...                ...        ...             ...
# 9239_0        snpArray        csv               2
# 9240_0  wholeGenomeSeq       cram               2
# 9241_0        snpArray        csv               2
# 9242_0  wholeGenomeSeq       cram               2
# 9243_0        snpArray        csv               2
#
# [9243 rows x 14 columns]

# %% [markdown]
# - fileId, fileSize, and currentVersion should already be in synapse
# - dataType, dataSubtype, Assay, fileFormat are annotations that should be pulled in from manifests
# - individual related metadata will be pull from individual manifests within projects

# %%
new_dm = [
    {
        "Attribute": "Individual Metadata",
        "Description": "Template for mapping individuals to files in synapse",
        "Valid Values": "",
        "DependsOn": "individualId, minAge, maxAge, Sex, Study, Diagnosis",
        "DependsOn Component": "",
        "Required": "False",
        "Properties": "Template",
        "Validation Rules": "",
        "Template": "",
        "Parent": "Template",
        "Ontology": "Sage Bionetworks",
        "UsedIn": "",
        "Module": "Cohort Builder",
    },
    {
        "Attribute": "Study",
        "Description": "",
        "Valid Values": "LLFS",
        "DependsOn": "",
        "DependsOn Component": "",
        "Required": "False",
        "Properties": "",
        "Validation Rules": "",
        "Template": "",
        "Parent": "DataProperty",
        "Ontology": "Sage Bionetworks",
        "UsedIn": "",
        "Module": "Cohort Builder",
    },
    {
        "Attribute": "minAge",
        "Description": "",
        "Valid Values": "",
        "DependsOn": "",
        "DependsOn Component": "",
        "Required": "False",
        "Properties": "",
        "Validation Rules": "int",
        "Template": "",
        "Parent": "DataProperty",
        "Ontology": "Sage Bionetworks",
        "UsedIn": "",
        "Module": "Cohort Builder",
    },
    {
        "Attribute": "maxAge",
        "Description": "",
        "Valid Values": "",
        "DependsOn": "",
        "DependsOn Component": "",
        "Required": "False",
        "Properties": "",
        "Validation Rules": "int",
        "Template": "",
        "Parent": "DataProperty",
        "Ontology": "Sage Bionetworks",
        "UsedIn": "",
        "Module": "Cohort Builder",
    },
    {
        "Attribute": "Diagnosis",
        "Description": "",
        "Valid Values": "",
        "DependsOn": "",
        "DependsOn Component": "",
        "Required": "False",
        "Properties": "",
        "Validation Rules": "",
        "Template": "",
        "Parent": "DataProperty",
        "Ontology": "Sage Bionetworks",
        "UsedIn": "",
        "Module": "Cohort Builder",
    },
    {
        "Attribute": "LLFS",
        "Description": "",
        "Valid Values": "",
        "DependsOn": "",
        "DependsOn Component": "",
        "Required": "False",
        "Properties": "",
        "Validation Rules": "",
        "Template": "",
        "Parent": "ValidValue",
        "Ontology": "Sage Bionetworks",
        "UsedIn": "",
        "Module": "Cohort Builder",
    },
    {
        "Attribute": "Assay",
        "Description": "",
        "Valid Values": "snpArray, 'wholeGenomeSeq",
        "DependsOn": "",
        "DependsOn Component": "",
        "Required": "False",
        "Properties": "DataProperty",
        "Validation Rules": "",
        "Template": "",
        "Parent": "Template",
        "Ontology": "Sage Bionetworks",
        "UsedIn": "",
        "Module": "Cohort Builder",
    },
    {
        "Attribute": "snpArray",
        "Description": "",
        "Valid Values": "",
        "DependsOn": "",
        "DependsOn Component": "",
        "Required": "False",
        "Properties": "",
        "Validation Rules": "",
        "Template": "",
        "Parent": "ValidValue",
        "Ontology": "Sage Bionetworks",
        "UsedIn": "",
        "Module": "Cohort Builder",
    },
    {
        "Attribute": "wholeGenomeSeq",
        "Description": "",
        "Valid Values": "snpArray, 'wholeGenomeSeq",
        "DependsOn": "",
        "DependsOn Component": "",
        "Required": "False",
        "Properties": "DataProperty",
        "Validation Rules": "",
        "Template": "",
        "Parent": "ValidValue",
        "Ontology": "Sage Bionetworks",
        "UsedIn": "",
        "Module": "Cohort Builder",
    },
    {
        "Attribute": "FileMapToIndividual",
        "Description": "Template for mapping individuals to files in synapse",
        "Valid Values": "",
        "DependsOn": "fileName, individualId",
        "DependsOn Component": "Individual Metadata",
        "Required": "False",
        "Properties": "Template",
        "Validation Rules": "",
        "Template": "",
        "Parent": "Template",
        "Ontology": "Sage Bionetworks",
        "UsedIn": "",
        "Module": "Cohort Builder",
    },
    {
        "Attribute": "fileName",
        "Description": "Name of the file",
        "Valid Values": "",
        "DependsOn": "",
        "Required": "True",
        "Properties": "DataProperty",
        "Validation Rules": "str",
        "Template": "FileToIndividualMap",
        "Parent": "DataProperty",
        "Ontology": "Sage Bionetworks",
        "UsedIn": "FileToIndividualMap",
        "Module": "Cohort Builder",
    },
    {
        "Attribute": "individualId",
        "Description": "Unique individual identifier",
        "Valid Values": "",
        "DependsOn": "",
        "Required": "True",
        "Properties": "DataProperty",
        "Validation Rules": "str",
        "Template": "FileToIndividualMap",
        "Parent": "DataProperty",
        "Ontology": "Sage Bionetworks",
        "UsedIn": "FileToIndividualMap",
        "Module": "Cohort Builder",
    },
    {
        "Attribute": "Template",
        "Description": "Template property for data model",
        "Valid Values": "",
        "DependsOn": "",
        "DependsOn Component" "Required": "",
        "Properties": "",
        "Validation Rules": "",
        "Template": "",
        "Parent": "Schema",
        "Ontology": "Sage Bionetworks",
        "UsedIn": "",
        "Module": "",
    },
    {
        "Attribute": "DataProperty",
        "Description": "Column for manifests",
        "Valid Values": "",
        "DependsOn": "",
        "Required": "",
        "Properties": "",
        "Validation Rules": "",
        "Template": "",
        "Parent": "Schema",
        "Ontology": "Sage Bionetworks",
        "UsedIn": "",
        "Module": "",
    },
    {
        "Attribute": "ValidValue",
        "Description": "valid value for dataProperty",
        "Valid Values": "",
        "DependsOn": "",
        "Required": "",
        "Properties": "",
        "Validation Rules": "",
        "Template": "",
        "Parent": "DataProperty",
        "Ontology": "Sage Bionetworks",
        "UsedIn": "",
        "Module": "",
    },
    {
        "Attribute": "Schema",
        "Description": "Schema property used in parent column",
        "Valid Values": "",
        "DependsOn": "",
        "Required": "",
        "Properties": "",
        "Validation Rules": "",
        "Template": "",
        "Parent": "",
        "Ontology": "Sage Bionetworks",
        "UsedIn": "",
        "Module": "",
    },
]

# %%
new_dm = pd.concat([dm, pd.DataFrame.from_dict(new_dm)])
print("Duplicates: ", sum(new_dm.duplicated(subset="Attribute")))
new_dm = new_dm.replace("", np.nan)
new_dm = new_dm.drop_duplicates(subset="Attribute", keep="first").sort_values(
    by=["Attribute"]
)

new_dm
# Out:
# Duplicates:  7
#              Attribute                                        Description  \
# 6                Assay                                                NaN
# 4         DataProperty                              teesting in schematic
# 4            Diagnosis                                                NaN
# 0  FileMapToIndividual                                           Template
# 0  Individual Metadata  Template for mapping individuals to files in s...
# 5                 LLFS                                                NaN
# 6               Schema              Schema property used in parent column
# 1                Study                                                NaN
# 3             Template                                 templalpte for dca
# 5           ValidValue                 valid value to be added to columns
# 1             fileName                                   Name of the file
# 2         individualId                       Unique individual identifier
# 3               maxAge                                                NaN
# 2               minAge                                                NaN
# 7             snpArray                                                NaN
# 8       wholeGenomeSeq                                                NaN
#
#                 Valid Values Required  \
# 6  snpArray, 'wholeGenomeSeq    False
# 4                        NaN      NaN
# 4                        NaN    False
# 0                        NaN    False
# 0                        NaN    False
# 5                        NaN    False
# 6                        NaN      NaN
# 1                       LLFS    False
# 3                        NaN      NaN
# 5                        NaN      NaN
# 1                        NaN     True
# 2                        NaN     True
# 3                        NaN    False
# 2                        NaN    False
# 7                        NaN    False
# 8  snpArray, 'wholeGenomeSeq    False
#
#                                            DependsOn DependsOn Component  \
# 6                                                NaN                 NaN
# 4                                                NaN                 NaN
# 4                                                NaN                 NaN
# 0                             fileName, individualId                 NaN
# 0  individualId, minAge, maxAge, Sex, Study, Diag...                 NaN
# 5                                                NaN                 NaN
# 6                                                NaN                 NaN
# 1                                                NaN                 NaN
# 3                                                NaN                 NaN
# 5                                                NaN                 NaN
# 1                                                NaN                 NaN
# 2                                                NaN                 NaN
# 3                                                NaN                 NaN
# 2                                                NaN                 NaN
# 7                                                NaN                 NaN
# 8                                                NaN                 NaN
#
#      Properties Validation Rules             Template        Parent  Source  \
# 6  DataProperty              NaN                  NaN      Template     NaN
# 4           NaN              NaN                  NaN      Template     NaN
# 4           NaN              NaN                  NaN  DataProperty     NaN
# 0      Template              NaN                 Self      Template     NaN
# 0      Template              NaN                  NaN      Template     NaN
# 5           NaN              NaN                  NaN    ValidValue     NaN
# 6           NaN              NaN                  NaN           NaN     NaN
# 1           NaN              NaN                  NaN  DataProperty     NaN
# 3           NaN              NaN                  NaN           NaN     NaN
# 5        schema              NaN                  NaN  DataProperty     NaN
# 1  DataProperty              str  FileToIndividualMap  DataProperty     NaN
# 2  DataProperty              str  FileToIndividualMap  DataProperty     NaN
# 3           NaN              int                  NaN  DataProperty     NaN
# 2           NaN              int                  NaN  DataProperty     NaN
# 7           NaN              NaN                  NaN    ValidValue     NaN
# 8  DataProperty              NaN                  NaN    ValidValue     NaN
#
#    Type          Ontology  Multivalue               UsedIn          Module  \
# 6   NaN  Sage Bionetworks         NaN                  NaN  Cohort Builder
# 4   NaN  Sage Bionetworks         NaN                  NaN             NaN
# 4   NaN  Sage Bionetworks         NaN                  NaN  Cohort Builder
# 0   NaN  Sage Bionetworks         NaN                  NaN  Cohort Builder
# 0   NaN  Sage Bionetworks         NaN                  NaN  Cohort Builder
# 5   NaN  Sage Bionetworks         NaN                  NaN  Cohort Builder
# 6   NaN  Sage Bionetworks         NaN                  NaN             NaN
# 1   NaN  Sage Bionetworks         NaN                  NaN  Cohort Builder
# 3   NaN  Sage Bionetworks         NaN                  NaN             NaN
# 5   NaN  Sage Bionetworks         NaN                  NaN             NaN
# 1   NaN  Sage Bionetworks         NaN  FileToIndividualMap  Cohort Builder
# 2   NaN  Sage Bionetworks         NaN  FileToIndividualMap  Cohort Builder
# 3   NaN  Sage Bionetworks         NaN                  NaN  Cohort Builder
# 2   NaN  Sage Bionetworks         NaN                  NaN  Cohort Builder
# 7   NaN  Sage Bionetworks         NaN                  NaN  Cohort Builder
# 8   NaN  Sage Bionetworks         NaN                  NaN  Cohort Builder
#
#    DependsOn ComponentRequired
# 6                          NaN
# 4                          NaN
# 4                          NaN
# 0                          NaN
# 0                          NaN
# 5                          NaN
# 6                          NaN
# 1                          NaN
# 3                          NaN
# 5                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 2                          NaN
# 7                          NaN
# 8                          NaN

# %%
new_dm.to_csv(csv_model, index=False)

# %%
# Create schematic model
localcube.create_json_model(csv_model, json_model)
# Out:
# Running
#  schematic schema convert /Users/nlee/Documents/Projects/cohort_builder_data_dictionary/cohort-builder-model.csv --output_jsonld /Users/nlee/Documents/Projects/cohort_builder_data_dictionary/cohort-builder-model.jsonld
# Starting schematic...
# Done adding requirements and value ranges to attributes
# The Data Model was created and saved to '/Users/nlee/Documents/Projects/cohort_builder_data_dictionary/cohort-builder-model.jsonld' location.
# Finished
